# %% [markdown]
# <a href="https://colab.research.google.com/github/sunyaxiong1996/local/blob/master/%E5%8D%88%E5%BE%8C2023_10_10%E5%85%BC%E5%B9%B3%E6%95%A6%E5%85%88%E7%94%9F%E3%80%80%E3%80%80%E3%81%8B%E3%81%AD%E3%81%B2%E3%82%89%E3%80%80%E3%81%82%E3%81%A4%E3%81%97.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS18 １，２単元　　たんげん
#
#
# ---
#
#
# # CS18 test
#
# **IT ワールド**
#
# **it 戦略**
#
# **科目　a**
#
# **科目　b**
#
#
#
# ---
#
#
# ## 平たい　　　ひらたい
#
#
# ---
#
#
# コンピューター　サイエンス
#
# science科学。自然科学。（学問。科学。特に、自然科学。）
#
# ## 基本情報技術者
#
# A 来年６．７月秋生できる　　　科目認定試験
#
# B　選択肢　　　２０題；　　　アルゴリズム　１６問
#
#
# ｊ検
#
# ## 応用情報技術者
#
# 午前　　４択
#
# 午後　　記述問題

# %% [markdown]
# # 第一部　　ハードウェア
#
# １コンピューター　の　基本構成
#
# １）　五大装置
#
# 演算装置　　　　　CPU------中央処理装置　しょり
#
# 制御そうち　　　　せいぎょ　装置
#
#  記憶　装置　　　　------　主億装置
#
#  ------------
#
# ```
# ** 周辺装置**
#
#
#  ==  補助装置　（　ほじょそうち）==
#
# == 入力　装置 ==
#
# == 出力　装置 ==
#
# ```

# %% [markdown]
# cpu
#
# ```
# 制御装置
#
# 演算装置
# ```

# %% [markdown]
# ![photo_2023-10-10_16-56-49.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![photo_2023-10-10_16-56-41.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # 記憶装置
#
#
# 1.主記憶装置　　　揮発性メモリ　　　　　　　　　きはつせい
#
# 電源**切断**で、記憶**消去**　　　　　　　　　せつだん　　　しょうきょ
#
# 2.補助記憶装置　　不揮発性メモリ　　　　　　　　ふきはつせい
#
# 電源**切断**で、記憶**保持**　　　　　　　　　ほじ

# %% [markdown]
# # 処理装置　プロセッサ　processor
#
# CPU:  center processing unit
#
# GPU:  グラフィッケス処理の高速化　------　AIで活用
#
# SOC:  system on a chip      必要な機能が　一片　に　しゅうやく　された　電子部品　　いっぺん　　　　（パソコンにふむき）不向き
#
# sip: system in a package     専用チップを　イボード　に　集約。
#
# ウンチプマイコン:         one chilp micro computer 单片机

# %% [markdown]
# # 第二部  コンピューター　ノ　　データ表現

# %% [markdown]
# 1. ダークの表現
#
# １）表現単位　　たんい
#
# 　　ビット　bit   2進数　　にしんすう
#
#
# 零　と　一　　　　　　　　　０と１
#
# **スラッシュ　　　／　　　**
